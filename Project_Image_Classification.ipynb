# %%
# Sources of data collection 

# 1. Manually from google search.
# 2. Use python and web scrapping. ( Download in automated way  , this is not much reliable) 
# 3. Chrome extension --> Fatkun  ( Download all the images of a tab ) 
# 4. Buy data from third party vendors .

# Web scrapping --> Web scraping, also known as web data extraction, is the process of using bots to automatically extract data from websites.

# %%
#  Data Cleaning | Image Classification 

#  For face & eyes detection, we will use OpenCV ( famous library for image processing )
    #  Haar - Cascade technique is famous for this purpose .

#  Raw images --> Cropped faces with 2 eyes using haar cascade --> Manual data cleaning ( removing unnecessary data ( images ) )   ----> Wavelet transformed images ---> Train model ( hyper tune )  ---> saved model 

                          
#      html / css / ----> python  flask 
#          js       <----    server
#                              ^
#                              |
#                          saved model

# %%
# In PyCharm , change interpreter using Conda Environment ( left topmost ) 

# when we upload image at frontend , then it is converted in string , then sent to backend

# %%
# Deployment 

# 1. change  var url = "/api/classify_image";    (  // for nginx  ) , from var url = "http://127.0.0.1:5000/classify_image";  ( in app.js file ) 

# 2. Download nginx from chrome ( zip file ) , unzip it in C:/Program Files .

      # in this extracted nginx folder open conf folder , then nginx.conf file ( with Notepad ++ ( if not present , then install notepad++) ) .


           # checking purpose --
             # after opening nginx.conf file ( ctrl+ s on notepad++ , allow whatever asked ) , double click on nginx.exe ( in nginx folder )
             # open chrome , search localhost ( or localhost:80) 
                   # if ( Welcome to nginx opens) then fine . 
                   # else ( IIS windows opens ) , then we need to disable IIS on port 80 , follow the steps below to disable IIS. ( in this case , nginx.exe woudn't have responded ) 
                      # click Windows + R  , type service.msc , then click ok . 
                      # now a panel opens , search for World Wide Web Publishing Service Properties ( Local Computer ) in the last , double click on it .
                      # then stop service status , then select ' disabled ' in ' startup type ' , click on 'Apply' ( in bottom right corner ) , then ok .
                   # now end task of nginx in task manager ( if present ) , then double click on nginx.exe
                   # now refresh localhost ( on browser ) , ' Welcome to nginx ' would be opening .  

           
           # in nginx.conf , in location change  ** root   "C:\Users\ayush\Image_classification_project\UI";  from ** root html; **( like this , means project folder ) and
           # ** index  index.html index.htm app.html app.htm;**   ( means app.html file , which is supposed to be shown on browser).
            # add the segment given below -
                    #    location /api/ {
		            #      rewrite ^/api(.*) $1 break;
			        #      proxy_pass http://127.0.0.1:5000;
		            #    } 

           #  now open task manager , end task of nginx and again double click on nginx.exe , refesh localhost , our project's home page will be visible . 
           # open server ( if present ) , refresh local host , our webpage on localhost will be fully functional . 


# 3.     Open AWS console in chrome , login , create ec2 instance . see codebasics video ( https://youtu.be/q8NOmLD5pTU?si=_RPNzVb_eD5744lQ ) , create in simialr manner .
       # Note:  In AWS EC2 instance , NGINX  serves as server ( light web server ) serves to http request .

       # Now in git-bash type ** ssh -i "C:\Users\ayush\.ssh\ic.pem" ubuntu@ec2-3-25-126-119.ap-southeast-2.compute.amazonaws.com ** ( means the ssh file , which we saved in .ssh folder as shown in video)
           # and ( ubuntu@ec2-3-25-126-119.ap-southeast-2.compute.amazonaws.com  ) is present in aws console , instance created and connect .

# 4.  In aws console , it will be written -  Connect to your instance using its Public DNS:
           #  ec2-3-25-126-119.ap-southeast-2.compute.amazonaws.com  ( copy this ) and download WinSCP from chrome and install it .
           # open WinSCP , a popup opens , in which paste the above copied text in hostname , username as ** ubuntu ** , then click on advanced ( below password ) 
                # then authentication on left , then go to folder , where we downloaded bhp.pem file ( as shown in video ) , ( select All Private Keys ) select , then select ok , then ok , then login 
                # follow video ( above , codebasics )  for any doubt .
           # after connection , drag and drop the project from our computer to ubuntu .


# 5.  Now again open git-bash ( after the execution of  ** ssh -i "C:\Users\ayush\.ssh\ic.pem" ubuntu@ec2-3-25-126-119.ap-southeast-2.compute.amazonaws.com ** ) , 
      ( #  if we type ** pwd ** then home/ubuntu is output . ( i.e. print working directory gives this ) ) 
    
    # 5.1   type ** sudo apt-get update ** , click enter
        #   type ** sudo apt-get install nginx **
        #   for checking status , type ** sudo service nginx status ** ( it will show active ( running ) , if somehow it fails then follow steps below to uninstall nginx ) 
                 # type ** sudo systemct1 stop nginx ** 
                 # then type ** sudo apt purge nginx nginx-common **
                 # then type ** sudo apt autoremove **
                 # then type **sudo apt clean **   ( after this repeat from step 5.1 ) 


       #  Note : click ** q ** to exit from any file ( if opened)  in bash .
       #  Now if we paste ** ec2-3-25-126-119.ap-southeast-2.compute.amazonaws.com ** , ** welcome to nginx ** opens . ( if 403 forbidden opens , then follow the following steps ) 
            # type  ** cd /etc/nginx/ ** ( going to installed nginx directory )
            #  type ** ll ** ( to view list of all the files ) 
            #  now type ** sudo nano nginx.conf ** ( to edit configuration file ) 
                   # in the first line write ** user ubuntu **  ( from  ** user www-data ** ) , then click ctrl + x , then ** y ** , then enter . ( we change conf file )
                   # now type ** sudo service nginx restart **  ( also can check status again ) 
            # now refresh chrome , ** welocme to nginx ** will open 
          
# 6. Now we have to change the file location of ngnix ,
        #  move in nginx directory ( by typing , cd /etc/nginx/ )
        # move to sites-enabled , type ** cd sites-enabled/**
        # now we have to disable default configuration , type ** sudo unlink default ** ( default file removed ) 
        # now move to sites-available ( type ** cd ../sites-available/ ** )
            #  here we have to create a file , ( type ** sudo vim bhp.conf ** ( or any other name as required ) ) and paste the given text below , in this new file 
                   # server {
                   #   listen 80;
                   #   server_name ic;
                   #   root /home/ubuntu/Image_classification_project/UI;
                   #   index app.html;
                   #   location /api/ {
                   #      rewrite ^/api(.*) $1 break;
                   #      proxy_pass http://127.0.0.1:5000;
                   #   }
                   # }  
               #  then type ** :wq** ( to save the file ) 
        # now we will create a symlink in sites enabled , ( type ** cd ../sites-enabled/ ** ) 
               # type ** sudo ln -v -s /etc/nginx/sites-available/ic.conf inside /etc/nginx/sites-enabled ** ( for symlink ) 
               # type ** ll ** ( to view all the files ) ( symlink is created )
            # but ,**  inside -> inside ** is also present ( we have to remove it , other error happens )
                 #  type ** sudo rm inside ** ( to remove this inside -> inside ) 

#  7. type ** sudo service nginx restart ** 
      # type ** sudo service nginx status ** ( it should be active ,if not then uninstall nginx as above and reinstall and follow same steps ) 
      #  now if we refresh browser ( ** ec2-3-25-126-119.ap-southeast-2.compute.amazonaws.com ** ) , then our homepage of  website opens , of our site ( project ) .( but backend not work here ) 


#  8.  Everything , fine till now , now we have to  setup backend of our project with respect to ubuntu . 
          #  type ** cd ~ **  ( moving to home directory ) 
          #  type ** cd Image_classification_project/server/ **  ( or whatever , that was drag and dropped in WinSCP ) 
          #  check python is installed or not . ( type ** python3 ** ) , now install pip3 ( type ** sudo apt install python-pip3 ) 
          #  install flask , opencv-python , ( and all required libraries ) using ** pip3 install flask ** ( likewise  install all )  
          
    #  Note : install OpenGL libraries on ubuntu . ( type ** sudo apt-get install libgl1-mesa-glx ** ) 
    #  Now type ** python3 server.py ** to run server , and refresh browser , everything will work fine .

# %%
# After whole deployement , how to run now deployed website,
#  Open chrome , search the deployed link ** ec2-3-25-126-119.ap-southeast-2.compute.amazonaws.com **
# open git bash , type  ** ssh -i "ic.pem" ubuntu@ec2-3-25-126-119.ap-southeast-2.compute.amazonaws.com **  ( now ubuntu opens ) 
# type cd Image_classification_project/server/    ( going to directory server in ubuntu , as saved in WinSCP ) 
  #  type ** python3 server.py**
